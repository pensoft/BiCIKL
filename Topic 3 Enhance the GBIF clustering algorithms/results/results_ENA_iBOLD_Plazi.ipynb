# %%
# %sql
select * from gbif.relationships_triple where id1 in (3349806846, 1264931755)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id1</th><th>id2</th><th>reasons</th><th>dataset1</th><th>dataset2</th><th>o1</th><th>o2</th></tr></thead><tbody><tr><td>1264931755</td><td>3349806846</td><td>SAME_ACCEPTED_SPECIES,NON_CONFLICTING_DATE,NON_CONFLICTING_COORDINATES,NON_CONFLICTING_COUNTRY,IDENTIFIERS_OVERLAP</td><td>fc003253-5eee-414e-84c8-817e12bdb708</td><td>d8cd16ba-bb74-4420-821e-083f2bac17c2</td><td>{"publishingOrgKey":"c361e830-181e-11da-9544-b8a03c50a862","classKey":"212","scientificName":"Cyanocorax yncas (Boddaert, 1783)","genericName":"Cyanocorax","year":null,"taxonRank":"SPECIES","fieldNumber":null,"decimalLatitude":null,"media":null,"kingdomKey":"1","preparations":"Liquid Nitrogen","catalogNumber":"6114","basisOfRecord":"PRESERVED_SPECIMEN","institutionCode":"LSUMZ","countryCode":"EC","phylumKey":"44","publishingOrgName":"Louisiana State University Museum of Natural Science","genusKey":"2482558","recordedByID":[],"acceptedScientificName":"Cyanocorax yncas (Boddaert, 1783)","day":null,"order":"Passeriformes","orderKey":"729","recordNumber":null,"datasetKey":"fc003253-5eee-414e-84c8-817e12bdb708","acceptedTaxonKey":"2482565","typeStatus":null,"datasetName":"LSUMZ Bird Tissues","decimalLongitude":null,"gbifId":1264931755,"collectionCode":"birdsTissues","occurrenceID":"urn:catalog:LSUMZ:birdsTissues:6114","taxonKey":"2482565","kingdom":"Animalia","familyKey":"5235","specificEpithet":"yncas","recordedBy":null,"phylum":"Chordata","otherCatalogNumbers":null,"month":null,"genus":"Cyanocorax","species":"Cyanocorax yncas","speciesKey":"2482565","family":"Corvidae","eventDate":null}</td><td>{"publishingOrgKey":"ada9d123-ddb4-467d-8891-806ea8d94230","classKey":"212","scientificName":"Cyanocorax yncas (Boddaert, 1783)","genericName":"Cyanocorax","year":null,"taxonRank":"SPECIES","fieldNumber":null,"decimalLatitude":null,"media":null,"kingdomKey":"1","preparations":null,"catalogNumber":"LSUMZ:6114","basisOfRecord":"PRESERVED_SPECIMEN","institutionCode":null,"countryCode":null,"phylumKey":"44","publishingOrgName":"European Nucleotide Archive (EMBL-EBI)","genusKey":"2482558","recordedByID":[],"acceptedScientificName":"Cyanocorax yncas (Boddaert, 1783)","day":null,"order":"Passeriformes","orderKey":"729","recordNumber":null,"datasetKey":"d8cd16ba-bb74-4420-821e-083f2bac17c2","acceptedTaxonKey":"2482565","typeStatus":null,"datasetName":"INSDC Sequences","decimalLongitude":null,"gbifId":3349806846,"collectionCode":null,"occurrenceID":"GU144890","taxonKey":"2482565","kingdom":"Animalia","familyKey":"5235","specificEpithet":"yncas","recordedBy":null,"phylum":"Chordata","otherCatalogNumbers":null,"month":null,"genus":"Cyanocorax","species":"Cyanocorax yncas","speciesKey":"2482565","family":"Corvidae","eventDate":null}</td></tr><tr><td>3349806846</td><td>1264931755</td><td>SAME_ACCEPTED_SPECIES,NON_CONFLICTING_DATE,NON_CONFLICTING_COORDINATES,NON_CONFLICTING_COUNTRY,IDENTIFIERS_OVERLAP</td><td>d8cd16ba-bb74-4420-821e-083f2bac17c2</td><td>fc003253-5eee-414e-84c8-817e12bdb708</td><td>{"publishingOrgKey":"ada9d123-ddb4-467d-8891-806ea8d94230","classKey":"212","scientificName":"Cyanocorax yncas (Boddaert, 1783)","genericName":"Cyanocorax","year":null,"taxonRank":"SPECIES","fieldNumber":null,"decimalLatitude":null,"media":null,"kingdomKey":"1","preparations":null,"catalogNumber":"LSUMZ:6114","basisOfRecord":"PRESERVED_SPECIMEN","institutionCode":null,"countryCode":null,"phylumKey":"44","publishingOrgName":"European Nucleotide Archive (EMBL-EBI)","genusKey":"2482558","recordedByID":[],"acceptedScientificName":"Cyanocorax yncas (Boddaert, 1783)","day":null,"order":"Passeriformes","orderKey":"729","recordNumber":null,"datasetKey":"d8cd16ba-bb74-4420-821e-083f2bac17c2","acceptedTaxonKey":"2482565","typeStatus":null,"datasetName":"INSDC Sequences","decimalLongitude":null,"gbifId":3349806846,"collectionCode":null,"occurrenceID":"GU144890","taxonKey":"2482565","kingdom ...

# %%
# %sql
-- ENA records in clusters before/after
select --count(distinct gbifid) as total_recs, 
  count(distinct bef.id1) as recs_clustered_b, count(distinct aft.id1) as recs_clustered,
  count(distinct bef.id2) as recs_linked_b, count(distinct aft.id2) as recs_linked
from gbif.occurrence 
left join gbif.relationships1 bef on bef.id1=gbifid
left join gbif.relationships_triple aft on aft.id1=gbifid
where datasetkey in ('d8cd16ba-bb74-4420-821e-083f2bac17c2', '393b8c26-e4e0-4dd0-a218-93fc074ebf4e', '583d91fe-bbc0-4b4a-afe1-801f88263016')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>recs_clustered_b</th><th>recs_clustered</th><th>recs_linked_b</th><th>recs_linked</th></tr></thead><tbody><tr><td>687701</td><td>1055489</td><td>872548</td><td>1273604</td></tr></tbody></table></div>

# %%
# %sql
-- ENA numbers grouped by dataset
select Left(title, 100) as Dataset, IfNull(bef.records, 0) as recs_clustered_b, aft.records as recs_clustered, 
  IfNull(bef.records_linked, 0) as recs_linked_b, aft.records_linked as recs_linked
from
  (select dataset2, count(distinct id1) as records, count(distinct id2) as records_linked
  from gbif.relationships1 where dataset1 in ('d8cd16ba-bb74-4420-821e-083f2bac17c2', '393b8c26-e4e0-4dd0-a218-93fc074ebf4e', '583d91fe-bbc0-4b4a-afe1-801f88263016')
  group by dataset2) as bef
full outer join
  (select dataset2, count(distinct id1) as records, count(distinct id2) as records_linked
  from gbif.relationships_triple where dataset1 in ('d8cd16ba-bb74-4420-821e-083f2bac17c2', '393b8c26-e4e0-4dd0-a218-93fc074ebf4e', '583d91fe-bbc0-4b4a-afe1-801f88263016')
  group by dataset2) as aft
on bef.dataset2=aft.dataset2
join gbif.datasets on aft.dataset2=dataset_key
order by recs_clustered desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>
University of Minnesota Insect Collection</td><td>469</td><td>469</td><td>1359</td><td>1359</td></tr><tr><td>UWFC Ichthyology Collection</td><td>356</td><td>431</td><td>361</td><td>421</td></tr><tr><td>Royal Ontario Museum Green Plant Herbarium (TRT)</td><td>423</td><td>424</td><td>438</td><td>439</td></tr><tr><td>University of British Columbia Herbarium (UBC) - Vascular Plant Collection</td><td>410</td><td>410</td><td>414</td><td>414</td></tr><tr><td>Natural History Museum (London) Collection Specimens</td><td>196</td><td>397</td><td>242</td><td>469</td></tr><tr><td>NHMD Entomology Collection</td><td>200</td><td>396</td><td>211</td><td>357</td></tr><tr><td>RBINS DaRWIN</td><td>8</td><td>395</td><td>10</td><td>397</td></tr><tr><td>Royal Belgian Institute of Natural Sciences Mollusc collection</td><td>0</td><td>387</td><td>0</td><td>387</td></tr><tr><td>Auckland Museum Botany Collection</td><td>69</td><td>379</td><td>69</td><td>368</td></tr><tr><td>Fish specimens of Kagoshima University Museum</td><td>8</td><td>341</td><td>8</td><td>3 ...

# %%
# %sql
-- iBOL totals
select --count(distinct gbifid) as total_recs, 
  count(distinct bef.id1) as recs_clustered_b, count(distinct aft.id1) as recs_clustered_after,
  count(distinct bef.id2) as recs_linked_b, count(distinct aft.id2) as recs_linked_after
from gbif.occurrence 
left join gbif.relationships1 bef on bef.id1=gbifid
left join gbif.relationships_triple aft on aft.id1=gbifid
where datasetkey='040c5662-da76-4782-a48e-cdea1892d14c'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>recs_clustered_b</th><th>recs_clustered_after</th><th>recs_linked_b</th><th>recs_linked_after</th></tr></thead><tbody><tr><td>821449</td><td>1196409</td><td>1069290</td><td>1425030</td></tr></tbody></table></div>

# %%
# %sql
-- iBOL
select Left(title, 100) as Dataset, IfNull(bef.records, 0) as recs_clustered_b, aft.records as recs_clustered, 
  IfNull(bef.records_linked, 0) as recs_linked_b, aft.records_linked as recs_linked
from
  (select dataset2, count(distinct id1) as records, count(distinct id2) as records_linked
  from gbif.relationships1 where dataset1='040c5662-da76-4782-a48e-cdea1892d14c' group by dataset2) as bef
full outer join
  (select dataset2, count(distinct id1) as records, count(distinct id2) as records_linked
  from gbif.relationships_triple where dataset1='040c5662-da76-4782-a48e-cdea1892d14c' group by dataset2) as aft
on bef.dataset2=aft.dataset2
join gbif.datasets on aft.dataset2=dataset_key
order by recs_clustered desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Dataset</th><th>recs_clustered_b</th><th>recs_clustered</th><th>recs_linked_b</th><th>recs_linked</th></tr></thead><tbody><tr><td>INSDC Sequences</td><td>602891</td><td>958760</td><td>602128</td><td>933240</td></tr><tr><td>Centre for Biodiversity Genomics - Canadian Specimens</td><td>149041</td><td>150425</td><td>150298</td><td>151682</td></tr><tr><td>Zoologische Staatssammlung Muenchen - International Barcode of Life (iBOL) - Barcode of Life Project</td><td>40567</td><td>41944</td><td>41760</td><td>43136</td></tr><tr><td>INSDC Host Organism Sequences</td><td>4543</td><td>16871</td><td>5202
td><td>1780</td><td>1782</td><td>1791</td></tr><tr><td>Centre for Biodiversity Genomics (BIOUG) - Marine Invertebrates</td><td>1729</td><td>1731</td><td>1712</td><td>1714</td></tr><tr><td>BioFokus</td><td>1707</td><td>1707</td><td>2725</td><td>2725</td></tr><tr><td>INSDC Environment Sample Sequences</td><td>1650</td><td>1675</td><td>1674</td><td>1699</td></tr><tr><td>Vascular plant herbarium, UiT Tromsø Muse ...

# %%
# %sql
-- Plazi totals
select --count(distinct gbifid) as total_recs, 
  count(distinct bef.id1) as recs_clustered_b, count(distinct aft.id1) as recs_clustered,
  count(distinct bef.id2) as recs_linked_b, count(distinct aft.id2) as recs_linked
from gbif.occurrence 
left join gbif.relationships1 bef on bef.id1=gbifid
left join gbif.relationships_triple aft on aft.id1=gbifid
where publishingorgkey='7ce8aef0-9e92-11dc-8738-b8a03c50a862'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>recs_clustered_b</th><th>recs_clustered</th><th>recs_linked_b</th><th>recs_linked</th></tr></thead><tbody><tr><td>34657</td><td>36897</td><td>44916</td><td>47346</td></tr></tbody></table></div>

# %%
# %sql
-- Plazi
select Left(aft.publishing_organization_title, 100) as Publisher, 
  IfNull(bef.records, 0) as recs_clustered_b, aft.records as recs_clustered, 
  IfNull(bef.records_linked, 0) as recs_linked_b, aft.records_linked as recs_linked
from
  (select d2.publishing_organization_title, count(distinct id1) as records, count(distinct id2) as records_linked
   from gbif.datasets d1
   join gbif.relationships1 on dataset1 = d1.dataset_key 
   join gbif.datasets d2 on dataset2=d2.dataset_key
   where d1.publishing_organization_key='7ce8aef0-9e92-11dc-8738-b8a03c50a862'
   group by d2.publishing_organization_title) as bef
full outer join
  (select d2.publishing_organization_title, count(distinct id1) as records, count(distinct id2) as records_linked
   from gbif.datasets d1
   join gbif.relationships_triple on dataset1 = d1.dataset_key 
   join gbif.datasets d2 on dataset2=d2.dataset_key
   where d1.publishing_organization_key='7ce8aef0-9e92-11dc-8738-b8a03c50a862'
   group by d2.publishing_organization_title) as aft
on bef.publishing_organization_title=aft.publishing_organization_title
order by recs_clustered desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Publisher</th><th>recs_clustered_b</th><th>recs_clustered</th><th>recs_linked_b</th><th>recs_linked</th></tr></thead><tbody><tr><td>Plazi.org taxonomic treatments database</td><td>4512</td><td>5160</td><td>4512</td><td>5160</td></tr><tr><td>National Museum of Natural History, Smithsonian Institution</td><td>4136</td><td>4565</td><td>2860</td><td>3298</td></tr><tr><td>Natural History Museum</td><td>3219</td><td>3435</td><td>2183</td><td>2372</td></tr><tr><td>MNHN - Museum national d'Histoire naturelle</td><td>2861</td><td>3002</td><td>2823</td><td>2962</td></tr><tr><td>California Academy of Sciences</td><td>2984</td><td>2994</td><td>4745</td><td>4754</td></tr><tr><td>Museum of Comparative Zoology, Harvard University</td><td>1450</td><td>1534</td><td>921</td><td>1003</td></tr><tr><td>Naturalis Biodiversity Center</td><td>1444</td><td>1485</td><td>1106</td><td