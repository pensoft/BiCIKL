# %% [markdown]
# # Try running clustering using just the first recorder name
#
# See: https://github.com/pensoft/BiCIKL/issues/28
#
# Building the markov chain model for team parsing in this environment took some time (training step)
# Loaded a datafile built externally to test the process, overwriting the recordedby value with the extracted forst team member.

# %%
do_setup = False
if do_setup:
  recordedby_first_team_member = 'dbfs:/FileStore/tables/agents_first_tm_csv.gz'
  sparkDF = spark.read.csv(recordedby_first_team_member, sep='\t', header="true", inferSchema="true")
  # Save as table
  sparkDF.write.mode('overwrite').saveAsTable('nickyn.occurrence_first_tm')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
USE nickyn;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DROP TABLE IF EXISTS occurrence;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Add an occurrence table with an extra column holding the first team member name (`first_tm`).

# %%
# %sql
    CREATE TABLE occurrence 
    AS
    SELECT *
    FROM gbif.occurrence;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Run original clustering, storing results in hash, candidates and relationships

# %%
# %sql
DROP TABLE IF EXISTS hash;
DROP TABLE IF EXISTS candidates;
DROP TABLE IF EXISTS relationships;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %scala
import org.gbif.pipelines.clustering.Cluster

val args = Array("--hive-db", "nickyn", "--hive-table-hashed", "hash", "--hive-table-candidates", "candidates", "--hive-table-relationships", "relationships")
Cluster.main(args)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Configuration: Map('hiveDatabase -&gt; nickyn, 'hiveTableHashed -&gt; hash, 'hiveTableCandidates -&gt; candidates, 'hiveTableRelationships -&gt; relationships)
# import org.gbif.pipelines.clustering.Cluster
# args: Array[String] = Array(--hive-db, nickyn, --hive-table-hashed, hash, --hive-table-candidates, candidates, --hive-table-relationships, relationships)
# </div>

# %% [markdown]
# How many relationships were created?

# %%
# %sql
SELECT count(DISTINCT id1), count(*) FROM relationships
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT id1)</th><th>count(1)</th></tr></thead><tbody><tr><td>19140426</td><td>115174986</td></tr></tbody></table></div>

# %%
# %sql
SELECT count(DISTINCT id1), count(*) 
FROM relationships
WHERE reasons LIKE '%SAME_RECORDER_NAME%'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT id1)</th><th>count(1)</th></tr></thead><tbody><tr><td>5342604</td><td>47744244</td></tr></tbody></table></div>

# %%
# %sql
SELECT occ1.gbifid, occ1.recordedby, occ2.gbifid, occ2.recordedby
FROM occurrence occ1 INNER JOIN relationships rel ON occ1.gbifid = rel.id1
  INNER JOIN occurrence occ2 on rel.id2 = occ2.gbifid
WHERE occ1.recordedby != occ2.recordedby
AND rel.REASONS LIKE '%SAME_RECORDER_NAME%'
LIMIT 50
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>gbifid</th><th>recordedby</th><th>gbifid</th><th>recordedby</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## Use the first team member instead of the full recordedby value

# %% [markdown]
# How many `recordedby` values exist?

# %%
# %sql
SELECT COUNT(DISTINCT first_tm)
FROM occurrence_first_tm
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT first_tm)</th></tr></thead><tbody><tr><td>989123</td></tr></tbody></table></div>

# %% [markdown]
# Update recordedby with first team member values

# %%
# %sql
MERGE INTO occurrence occ
USING occurrence_first_tm occftm
ON occ.gbifid = occftm.gbifIDsRecordedBy
WHEN MATCHED AND occftm.first_tm IS NOT NULL THEN
  UPDATE SET occ.recordedby = occftm.first_tm
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>40075774</td><td>40075774</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# Run clustering, storing results in hash_rb, candidates_rb and relationships_rb

# %%
# %sql
DROP TABLE IF EXISTS hash_rb;
DROP TABLE IF EXISTS candidates_rb;
DROP TABLE IF EXISTS relationships_rb;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %scala
import org.gbif.pipelines.clustering.Cluster

val args = Array("--hive-db", "nickyn", "--hive-table-hashed", "hash_rb", "--hive-table-candidates", "candidates_rb", "--hive-table-relationships", "relationships_rb")
Cluster.main(args)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Configuration: Map('hiveDatabase -&gt; nickyn, 'hiveTableHashed -&gt; hash_rb, 'hiveTableCandidates -&gt; candidates_rb, 'hiveTableRelationships -&gt; relationships_rb)
# import org.gbif.pipelines.clustering.Cluster
# args: Array[String] = Array(--hive-db, nickyn, --hive-table-hashed, hash_rb, --hive-table-candidates, candidates_rb, --hive-table-relationships, relationships_rb)
# </div>

# %%
# %sql
SELECT count(DISTINCT id1), count(*) 
FROM relationships_rb;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT id1)</th><th>count(1)</th></tr></thead><tbody><tr><td>19148555</td><td>114924512</td></tr></tbody></table></div>

# %%
# %sql
SELECT count(DISTINCT id1), count(*) 
FROM relationships_rb
WHERE reasons LIKE '%SAME_RECORDER_NAME%'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT id1)</th><th>count(1)</th></tr></thead><tbody><tr><td>5772420</td><td>47660604</td></tr></tbody></table></div>

# %%
# %sql
SELECT occ1.gbifid, occ1.recordedby, occ2.gbifid, occ2.recordedby
FROM gbif.occurrence occ1 INNER JOIN relationships_rb rel ON occ1.gbifid = rel.id1
  INNER JOIN gbif.occurrence occ2 on rel.id2 = occ2.gbifid
WHERE occ1.recordedby != occ2.recordedby
AND rel.REASONS LIKE '%SAME_RECORDER_NAME%'
LIMIT 50
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>gbifid</th><th>recordedby</th><th>gbifid</th><th>recordedby</th></tr></thead><tbody><tr><td>202122577</td><td>Aistleitner Eyjolf</td><td>18835907</td><td>Aistleitner Eyjolf, Aistleitner Ulrich</td></tr><tr><td>202122473</td><td>Aistleitner Eyjolf</td><td>18835907</td><td>Aistleitner Eyjolf, Aistleitner Ulrich</td></tr><tr><td>1323824652</td><td>Liv Borgen, Torstein Engelskjøn</td><td>21431005</td><td>Liv Borgen | Torstein Engelskjøn</td></tr><tr><td>111302249</td><td>B. Cabezudo & L. EspaÃ±a</td><td>29590540</td><td>B. Cabezudo & L. España</td></tr><tr><td>1419000608</td><td>Bueno, J.; Barba, R.; Contreras, A.</td><td>46404516</td><td>Bueno, J. & Barba, R. & Contreras, A.</td></tr><tr><td>2807369346</td><td>John Taylor|Connie Taylor</td><td>177032220</td><td>John Taylor; Connie Taylor</td></tr><tr><td>1851339243</td><td>Molero Mesa,Pérez Raya & Martínez Parras</td><td>196092613</td><td>Molero Mesa, Pérez Raya & Martínez Parras</td></tr><tr><td>1261131986</td><td>Thomas B. Croat|Dylan P. Hannon</td><td>218943009</td><td>Thomas B. Croat</td></tr><tr><td>2814928567</td><td>Marshall C. Johnston|Fernando Chiang-Cabrera|Tom Wendt|James S. Henrickson</td><td>218945999</td